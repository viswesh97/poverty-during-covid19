# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("E:/poverty_data/train_data.csv")
test_data = pd.read_csv("E:/poverty_data/test_data.csv")
data.head()
# Out:
#    S NO                     Country             World Region   Poverty  \
# 0     1                 Afghanistan               South Asia      Poor
# 1     2                     Albania  Europe and Central Asia  Not Poor
# 2     3                  Bangladesh               South Asia  Not Poor
# 3     4                       Benin       Sub-Saharan Africa      Poor
# 4     5  Congo, Democratic Republic       Sub-Saharan Africa      Poor
#
#    Multidimensional Poverty Index\n (MPI = H*A)  \
# 0                                         0.273
# 1                                         0.003
# 2                                         0.104
# 3                                         0.368
# 4                                         0.331
#
#    Headcount ratio: Population in multidimensional poverty  \
# 0                                              56.10
# 1                                               0.70
# 2                                              24.64
# 3                                              66.80
# 4                                              64.52
#
#    Intensity of deprivation among the poor  Nutrition  Child Mortality  \
# 0                                    48.70        NaN             8.51
# 1                                    39.10       0.46             0.00
# 2                                    42.23       9.48             1.30
# 3                                    55.00      35.62            10.36
# 4                                    51.33      38.78             7.19
#
#    Years of Schooling  School Attendance  Cooking Fuel  Sanitation  \
# 0               31.39              42.04         49.38       48.83
# 1                0.52               0.39          0.29        0.14
# 2               16.72               6.78         23.35       15.59
# 3               44.34              35.68         66.35       64.48
# 4               16.45              23.00         63.82       59.74
#
#    Drinking Water  Electricity  Housing  Assets  GDP  Population  \
# 0           30.16        23.69    54.66   13.87  3.9    38928346
# 1            0.21         0.00     0.14    0.05  2.2     2877797
# 2            1.43         4.62    23.33   16.14  8.2   164689383
# 3           37.31        55.08    42.91   17.69  6.9    12123200
# 4           50.72        57.68    59.24   48.69  4.4    89561403
#
#    Yearly change
# 0           2.33
# 1          -0.11
# 2           1.01
# 3           2.73
# 4           3.19

# %%
data.isnull().sum()
# Out:
# S NO                                                       0
# Country                                                    0
# World Region                                               0
# Poverty                                                    0
# Multidimensional Poverty Index\n (MPI = H*A)               0
# Headcount ratio: Population in multidimensional poverty    0
# Intensity of deprivation among the poor                    0
# Nutrition                                                  4
# Child Mortality                                            0
# Years of Schooling                                         0
# School Attendance                                          0
# Cooking Fuel                                               0
# Sanitation                                                 0
# Drinking Water                                             0
# Electricity                                                0
# Housing                                                    1
# Assets                                                     0
# GDP                                                        0
# Population                                                 0
# Yearly change                                              0
# dtype: int64

# %%
test_data.isnull().sum()
# Out:
# S NO                                                       0
# Country                                                    0
# World Region                                               0
# Multidimensional Poverty Index\n (MPI = H*A)               0
# Headcount ratio: Population in multidimensional poverty    0
# Intensity of deprivation among the poor                    0
# Nutrition                                                  0
# Child Mortality                                            1
# Years of Schooling                                         0
# School Attendance                                          0
# Cooking Fuel                                               0
# Sanitation                                                 0
# Drinking Water                                             0
# Electricity                                                0
# Housing                                                    0
# Assets                                                     0
# GDP                                                        0
# Population                                                 0
# Yearly change                                              0
# dtype: int64

# %%
data=data.fillna(value=0)
test_data = test_data.fillna(value=0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
fig, ax = plt.subplots(figsize = (20,10))
sns.barplot(x=data["Multidimensional Poverty Index\n (MPI = H*A)"],y=data["Country"],data=data,ci=None,ax=ax)
plt.xlabel("MPI")
plt.ylabel("Country")
plt.show()

# %%
fig, ax = plt.subplots(figsize = (40,10))
sns.lineplot(x=data['GDP'],y=data['Multidimensional Poverty Index\n (MPI = H*A)'],data=data,sort=True,ax=ax)
plt.xlabel("GDP")
plt.ylabel("MPI")
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20,10))
sns.barplot(x=data["Child Mortality"],y=data["Multidimensional Poverty Index\n (MPI = H*A)"],data=data,ax=ax)
plt.xlabel("Child Mortality")
plt.ylabel("MPI")
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20,10))
sns.scatterplot(x=data["World Region"],y=data["Country"],hue=data['Poverty'],data=data,ax=ax)
plt.xlabel("World Region")
plt.ylabel("Country")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
Country_encoder=LabelEncoder()
data["Country"]=Country_encoder.fit_transform(data["Country"])
Region_encoder=LabelEncoder()
data["World Region"]=Region_encoder.fit_transform(data["World Region"])
Poverty_encoder=LabelEncoder()
data["Poverty"]=Poverty_encoder.fit_transform(data["Poverty"])

# %%
data.head()
# Out:
#    S NO  Country  World Region  Poverty  \
# 0     1        0             4        1
# 1     2        1             2        0
# 2     3        2             4        0
# 3     4        3             5        1
# 4     5        5             5        1
#
#    Multidimensional Poverty Index\n (MPI = H*A)  \
# 0                                         0.273
# 1                                         0.003
# 2                                         0.104
# 3                                         0.368
# 4                                         0.331
#
#    Headcount ratio: Population in multidimensional poverty  \
# 0                                              56.10
# 1                                               0.70
# 2                                              24.64
# 3                                              66.80
# 4                                              64.52
#
#    Intensity of deprivation among the poor  Nutrition  Child Mortality  \
# 0                                    48.70       0.00             8.51
# 1                                    39.10       0.46             0.00
# 2                                    42.23       9.48             1.30
# 3                                    55.00      35.62            10.36
# 4                                    51.33      38.78             7.19
#
#    Years of Schooling  School Attendance  Cooking Fuel  Sanitation  \
# 0               31.39              42.04         49.38       48.83
# 1                0.52               0.39          0.29        0.14
# 2               16.72               6.78         23.35       15.59
# 3               44.34              35.68         66.35       64.48
# 4               16.45              23.00         63.82       59.74
#
#    Drinking Water  Electricity  Housing  Assets  GDP  Population  \
# 0           30.16        23.69    54.66   13.87  3.9    38928346
# 1            0.21         0.00     0.14    0.05  2.2     2877797
# 2            1.43         4.62    23.33   16.14  8.2   164689383
# 3           37.31        55.08    42.91   17.69  6.9    12123200
# 4           50.72        57.68    59.24   48.69  4.4    89561403
#
#    Yearly change
# 0           2.33
# 1          -0.11
# 2           1.01
# 3           2.73
# 4           3.19

# %%
data=data.drop(columns='S NO')

# %%
x= data.drop(columns='Poverty')
y= data['Poverty']

# %%
x=np.array(x)
y=np.array(y)

# %%
x.shape,y.shape
# Out:
# ((24, 18), (24,))

# %%
from sklearn.preprocessing import StandardScaler
scalerx=StandardScaler()
x=scalerx.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.40,random_state=6)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((14, 18), (10, 18), (14,), (10,))

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(random_state=6,min_samples_split=4)
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(min_samples_split=4, random_state=6)

# %%
train_pred=model.predict(x_train)
test_pred=model.predict(x_test)

# %%
train_score=model.score(x_train,train_pred)
train_score = round(train_score, 4)*100
print('Training Score = {} %'.format(train_score))

test_score=model.score(x_test,test_pred)
test_score = round(test_score, 4)*100
print('Testing Score = {} %'.format(test_score))
# Out:
# Training Score = 100.0 %
# Testing Score = 100.0 %

# %%
from sklearn.metrics import classification_report
print(classification_report(y_train,train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       1.00      1.00      1.00         7
#
#     accuracy                           1.00        14
#    macro avg       1.00      1.00      1.00        14
# weighted avg       1.00      1.00      1.00        14

# %%
Country = test_data["Country"]
Region = test_data["World Region"]
Country.to_csv("E:\project\Country.csv",index=False)
Region.to_csv("E:\poverty_data\Region.csv",index=False)

# %%
Country1_encoder=LabelEncoder()
test_data["Country"]=Country1_encoder.fit_transform(test_data["Country"])
Region1_encoder=LabelEncoder()
test_data["World Region"]=Region1_encoder.fit_transform(test_data["World Region"])

# %%
test_data=test_data.drop(columns='S NO')

# %%
test_data.shape
# Out:
# (12, 18)

# %%
scalerx=StandardScaler()
test_data=scalerx.fit_transform(test_data)

# %%
test_prediction=model.predict(test_data)

# %%
results=pd.DataFrame(data=test_prediction,columns=['Poverty']).round(2)

# %%
print(classification_report(results,test_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      1.00      1.00         7
#
#     accuracy                           1.00        12
#    macro avg       1.00      1.00      1.00        12
# weighted avg       1.00      1.00      1.00        12

# %%
results.replace(to_replace={0:'Not Poor',1:'Poor'},inplace=True)

# %%
Result = pd.concat([Country,Region,results], axis=1)
Result
# Out:
#          Country                     World Region   Poverty
# 0   Sierra Leone               Sub-Saharan Africa      Poor
# 1        Burundi               Sub-Saharan Africa      Poor
# 2          Niger               Sub-Saharan Africa      Poor
# 3   South Africa               Sub-Saharan Africa  Not Poor
# 4    South Sudan               Sub-Saharan Africa      Poor
# 5          Sudan                      Arab States      Poor
# 6     Tajikistan          Europe And Central Asia  Not Poor
# 7       Tanzania               Sub-Saharan Africa      Poor
# 8       Thailand        East Asia and the Pacific  Not Poor
# 9         Mexico  Latin America and the Carribean  Not Poor
# 10        Jordan                      Arab States  Not Poor
# 11        Uganda               Sub-Saharan Africa      Poor

# %%
fig, ax = plt.subplots(figsize = (20,10))
sns.scatterplot(x=Result["World Region"],y=Result["Country"],hue=Result['Poverty'],data=Result,ax=ax)
plt.xlabel("World Region")
plt.ylabel("Country")
plt.show()
